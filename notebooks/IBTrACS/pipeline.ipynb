# %%
import os
import shutil
import logging
import urllib.request
import pandas as pd
import geopandas as gpd
from osgeo import gdal, ogr
from zipfile import ZipFile

# %%
# Set up logging
logging.basicConfig(level=logging.INFO)

# %%
# Subset
SUBSET = 'ACTIVE'
# File type
FILE_TYPE = 'shapefile'
# Geometry type
GEOMETRY_TYPE = 'points'
# Version
DATASET_VERSION = 'v04r00'
# File extension (without dot)
FILE_EXTENSION = 'zip'

# %%
# Dataset URL
base_url = f'https://www.ncei.noaa.gov/data/international-best-track-archive-for-climate-stewardship-ibtracs/'
if FILE_TYPE == 'netcdf':
    url = f'{base_url}/{DATASET_VERSION}/access/{FILE_TYPE}/IBTrACS.{SUBSET}.{DATASET_VERSION}.{FILE_TYPE}'
elif FILE_TYPE == 'csv':
    url = f'{base_url}/{DATASET_VERSION}/access/{FILE_TYPE}/ibtracs.{SUBSET}.list.{DATASET_VERSION}.{FILE_TYPE}'
elif FILE_TYPE == 'shapefile':
    url = f'{base_url}/{DATASET_VERSION}/access/{FILE_TYPE}/IBTrACS.{SUBSET}.list.{DATASET_VERSION}.{GEOMETRY_TYPE}.{FILE_EXTENSION}'
else:
    raise ValueError(f'Unknown file type: {FILE_TYPE}, must be one of: netcdf, csv, shapefile')

# Dataset Filename
filename = os.path.basename(url)

# Data Directory
data_dir = os.path.abspath(os.path.join(
    os.path.dirname(os.path.dirname(os.getcwd())),
    'data', 'IBTrACS', FILE_TYPE, SUBSET.lower()))

# Recreate data directory
logging.info(f'Recreating data directory: {data_dir}')
if os.path.exists(data_dir):
    shutil.rmtree(data_dir)
os.makedirs(data_dir)
# Out:
# INFO:root:Recreating data directory: /Users/mtulow/projects/geospatial_analytics/monitor-tropical-storms/data/IBTrACS/shapefile/active

# %%
# Download data
logging.info(f'Downloading {filename} ...')
output_file, msg = urllib.request.urlretrieve(url, filename)

# If shapefile, extract files from archive into data directory 
if FILE_TYPE == 'shapefile':
    logging.info(f'Unzipping {filename} into {data_dir} ...')
    with ZipFile(filename, 'r') as zipObj:
        members = []
        for member in zipObj.namelist():
            members.append(member)
        zipObj.extractall(data_dir)

    # Rename files
    for old in members:
        new = '{}_{}.{}'.format(SUBSET, GEOMETRY_TYPE, old.split('.')[-1]).lower()
        src = os.path.join(data_dir, old)
        dst = os.path.join(data_dir, new)
        os.rename(src, dst)


    # Delete zip file
    logging.info(f'Removing {filename} ...')
    os.remove(filename)

# Construct path to file
if FILE_TYPE == 'netcdf' and FILE_TYPE == 'csv':
    file_path = os.path.join(data_dir, filename)
elif FILE_TYPE == 'shapefile':
    file_path = os.path.join(data_dir, '{}_{}.{}'.format(SUBSET, GEOMETRY_TYPE, 'shp').lower())

# Assert file exists
assert os.path.exists(file_path), f'File {file_path} does not exist'
# Out:
# INFO:root:Downloading IBTrACS.ACTIVE.list.v04r00.points.zip ...
# INFO:root:Unzipping IBTrACS.ACTIVE.list.v04r00.points.zip into /Users/mtulow/projects/geospatial_analytics/monitor-tropical-storms/data/IBTrACS/shapefile/active ...
# INFO:root:Removing IBTrACS.ACTIVE.list.v04r00.points.zip ...

# %%
# Read file
logging.info(f'Reading {file_path} ...')
if FILE_TYPE == 'shapefile':
    shapefile = ogr.Open(file_path)
# Out:
# INFO:root:Reading /Users/mtulow/projects/geospatial_analytics/monitor-tropical-storms/data/IBTrACS/shapefile/active/active_points.shp ...

# %%
layer = shapefile.GetLayer()
spatial_ref = layer.GetSpatialRef()
for i in range(layer.GetFeatureCount()):
    feature = layer.GetFeature(i)
    attributes = pd.Series(feature.items())
    name = feature.GetField('NAME')
    geometry = feature.GetGeometryRef()
    print()
    print(f'{i}: {name}\n'\
          f'{spatial_ref}\n'\
          f'{geometry.GetGeometryName()}({geometry.GetX()}, {geometry.GetY()})\n'\
          f'\t{attributes}')
# Out:
# 0: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.9000015258789, -9.399999618530273)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    15
# hour                   12
# min                     0
# Length: 168, dtype: object
#
# 1: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.87000274658203, -9.430000305175781)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    15
# hour                   15
# min                     0
# Length: 168, dtype: object
#
# 2: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.9000015258789, -9.5)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    15
# hour                   18
# min                     0
# Length: 168, dtype: object
#
# 3: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.0199966430664, -9.630000114440918)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    15
# hour                   21
# min                     0
# Length: 168, dtype: object
#
# 4: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.0999984741211, -9.699999809265137)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    16
# hour                    0
# min                     0
# Length: 168, dtype: object
#
# 5: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.95999908447266, -9.539999961853027)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    16
# hour                    3
# min                     0
# Length: 168, dtype: object
#
# 6: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.80000305175781, -9.399999618530273)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    16
# hour                    6
# min                     0
# Length: 168, dtype: object
#
# 7: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.80000305175781, -9.539999961853027)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    16
# hour                    9
# min                     0
# Length: 168, dtype: object
#
# 8: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.9000015258789, -9.699999809265137)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    16
# hour                   12
# min                     0
# Length: 168, dtype: object
#
# 9: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.06999969482422, -9.600000381469727)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    16
# hour                   15
# min                     0
# Length: 168, dtype: object
#
# 10: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.19999694824219, -9.5)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    16
# hour                   18
# min                     0
# Length: 168, dtype: object
#
# 11: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.18000030517578, -9.609999656677246)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    16
# hour                   21
# min                     0
# Length: 168, dtype: object
#
# 12: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.0999984741211, -9.800000190734863)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    17
# hour                    0
# min                     0
# Length: 168, dtype: object
#
# 13: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.04000091552734, -9.949999809265137)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    17
# hour                    3
# min                     0
# Length: 168, dtype: object
#
# 14: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.0, -10.100000381469727)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    17
# hour                    6
# min                     0
# Length: 168, dtype: object
#
# 15: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.98999786376953, -10.260000228881836)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    17
# hour                    9
# min                     0
# Length: 168, dtype: object
#
# 16: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.0, -10.399999618530273)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    17
# hour                   12
# min                     0
# Length: 168, dtype: object
#
# 17: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.01000213623047, -10.510000228881836)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    17
# hour                   15
# min                     0
# Length: 168, dtype: object
#
# 18: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(94.0, -10.600000381469727)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    17
# hour                   18
# min                     0
# Length: 168, dtype: object
#
# 19: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.95999908447266, -10.65999984741211)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    17
# hour                   21
# min                     0
# Length: 168, dtype: object
#
# 20: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.9000015258789, -10.800000190734863)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    18
# hour                    0
# min                     0
# Length: 168, dtype: object
#
# 21: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.8499984741211, -11.130000114440918)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    18
# hour                    3
# min                     0
# Length: 168, dtype: object
#
# 22: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.80000305175781, -11.5)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    18
# hour                    6
# min                     0
# Length: 168, dtype: object
#
# 23: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.77999877929688, -11.789999961853027)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    18
# hour                    9
# min                     0
# Length: 168, dtype: object
#
# 24: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.69999694824219, -12.0)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    18
# hour                   12
# min                     0
# Length: 168, dtype: object
#
# 25: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.47000122070312, -12.119999885559082)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    18
# hour                   15
# min                     0
# Length: 168, dtype: object
#
# 26: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(93.19999694824219, -12.199999809265137)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    18
# hour                   18
# min                     0
# Length: 168, dtype: object
#
# 27: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.95999908447266, -12.319999694824219)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    18
# hour                   21
# min                     0
# Length: 168, dtype: object
#
# 28: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.80000305175781, -12.399999618530273)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    19
# hour                    0
# min                     0
# Length: 168, dtype: object
#
# 29: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.83000183105469, -12.399999618530273)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    19
# hour                    3
# min                     0
# Length: 168, dtype: object
#
# 30: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.9000015258789, -12.399999618530273)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    19
# hour                    6
# min                     0
# Length: 168, dtype: object
#
# 31: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.83000183105469, -12.489999771118164)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    19
# hour                    9
# min                     0
# Length: 168, dtype: object
#
# 32: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.69999694824219, -12.600000381469727)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    19
# hour                   12
# min                     0
# Length: 168, dtype: object
#
# 33: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.51000213623047, -12.6899995803833)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    19
# hour                   15
# min                     0
# Length: 168, dtype: object
#
# 34: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.4000015258789, -12.699999809265137)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    19
# hour                   18
# min                     0
# Length: 168, dtype: object
#
# 35: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.58999633789062, -12.550000190734863)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    19
# hour                   21
# min                     0
# Length: 168, dtype: object
#
# 36: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.80000305175781, -12.399999618530273)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    20
# hour                    0
# min                     0
# Length: 168, dtype: object
#
# 37: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.73999786376953, -12.430000305175781)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    20
# hour                    3
# min                     0
# Length: 168, dtype: object
#
# 38: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.5999984741211, -12.5)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    20
# hour                    6
# min                     0
# Length: 168, dtype: object
#
# 39: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.47000122070312, -12.489999771118164)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    20
# hour                    9
# min                     0
# Length: 168, dtype: object
#
# 40: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.4000015258789, -12.399999618530273)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    20
# hour                   12
# min                     0
# Length: 168, dtype: object
#
# 41: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.51000213623047, -12.1899995803833)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    20
# hour                   15
# min                     0
# Length: 168, dtype: object
#
# 42: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92.5999984741211, -12.0)
# 	SID         2024016S09094
# SEASON               2024
# NUMBER                  3
# BASIN                  SI
# SUBBASIN               WA
#                 ...
# year                 2024
# month                   1
# day                    20
# hour                   18
# min                     0
# Length: 168, dtype: object
#
# 43: ANGGREK
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563,
#             AUTHORITY["EPSG","7030"]],
#         AUTHORITY["EPSG","6326"]],
#     PRIMEM["Greenwich",0,
#         AUTHORITY["EPSG","8901"]],
#     UNIT["degree",0.0174532925199433,
#         AUTHORITY["EPSG","9122"]],
#     AXIS["Latitude",NORTH],
#     AXIS["Longitude",EAST],
#     AUTHORITY["EPSG","4326"]]
# POINT(92